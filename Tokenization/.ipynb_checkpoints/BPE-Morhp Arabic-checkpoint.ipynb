# %%
# %reload_ext autoreload
# %autoreload 2
import bpe_surgery
import evaluate
import utils
import time
import pickle

# %%
gold_tokens = utils.get_gold_segmentations(dataset="/home/zaid/camelTB")
corpus = " ".join(list(gold_tokens))

# %%
results = {}
vocab_sizes = [300, 500, 1000, 5000]

for vocab_size in vocab_sizes:
    results_per_vocab = {}
    tokenizers = [bpe_surgery.bpe(vocab_size, lang='ar',), 
              bpe_surgery.bpe(vocab_size, morph = True, lang='ar', morph_with_sep=True)]
    for tokenizer in tokenizers:
        tokenizer_index = vocab_sizes.index(vocab_size)
        if tokenizer_index > 0:
            prev_tokenizer_vocab_size = vocab_sizes[tokenizer_index - 1]
            prev_tokenizer_name = "bpe"
            if tokenizer.morph:
                prev_tokenizer_name += "-morph"
            prev_tokenizer_name += f"-ar-{prev_tokenizer_vocab_size}"
            try:
                print("loading from previous tokenizer checkpoint")
                tokenizer.load(prev_tokenizer_name)
            except:
                print("error in loading prev tokenizer")
        print(f"training {tokenizer.name}")
        start_time = time.time()
        tokenizer.train(file = 'test_ar.txt')
        end_time = time.time()
        print('evaluating: ', tokenizer.name)
        r1 = evaluate.evaluate_on_segmentation(corpus, gold_tokens, tokenizer)
        r2 = evaluate.evaluate_on_compression_factor(corpus, tokenizer)
        r3 = end_time - start_time
        r4 = evaluate.evaluate_on_inf_speed(corpus, tokenizer)
        r5 = evaluate.evaluate_on_num_tokens(corpus, tokenizer)
        r6 = evaluate.evaluate_on_token_length(tokenizer)

        results_per_vocab[tokenizer.name] = [{"segmentation": r1}, {"compression factor":r2}, {"training speed":r3}, {"inference speed":r4},
                                   {"num of tokens":r5}, {"token length":r6}]
        tokenizer.save('.')
        with open(f"{tokenizer.name}/results.pl", 'wb') as handle:
            pickle.dump(results_per_vocab, handle, protocol=pickle.HIGHEST_PROTOCOL)
    results[vocab_size] = results_per_vocab
# Out:
# [nltk_data] Downloading package punkt to /home/zaid/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /home/zaid/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# training bpe-ar-300
#   0%|          | 0/229 [00:00<?, ?it/s]
# vocab size reached
# evaluating:  bpe-ar-300
#   0%|          | 0/14322 [00:00<?, ?it/s]
#   0%|          | 0/14322 [00:00<?, ?it/s]
#   0%|          | 0/14322 [00:00<?, ?it/s]
#   0%|          | 0/14322 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
# training bpe-morph-ar-300
# extracting affixes automatically ...
#   0%|          | 0/175 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-d4d03c037b81> in <module>()
#       9         print(f"training {tokenizer.name}")
#      10         start_time = time.time()
# ---> 11         tokenizer.train(file = 'test_ar.txt')
#      12         end_time = time.time()
#      13         print('evaluating: ', tokenizer.name)
#
# ~/DISS/Tokenization/bpe_surgery.py in train(self, text, file)
#     322     pbar = tqdm(total=self.vocab_size - len(self.vocab))
#     323     while True:
# --> 324       grams = self.get_pairs_dict(self.corpus, check_morph_sep= self.morph_with_sep)
#     325
#     326       # this is from sentence piece, it seems to break up ties in this way
#
# ~/DISS/Tokenization/bpe_surgery.py in get_pairs_dict(self, t, check_morph_sep)
#     170         if bigram[0] == UNK:
#     171           continue
# --> 172         if check_morph_sep and self.has_morph_sep(bigram):
#     173           continue
#     174         grams[bigram] += t[word]
#
# ~/DISS/Tokenization/bpe_surgery.py in has_morph_sep(self, bigram)
#     130     returns: bool value
#     131     """
# --> 132     if (bigram[0] + MORPH_SEP in self.vocab) or (MORPH_SEP + bigram[1] in self.vocab):
#     133       # print("can't merge ", bigram)
#     134       return True
#
# KeyboardInterrupt:

# %%
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as plt
for i in range(6):
    names = []
    values = [] 
    vocabs = []
    for vocab_size in results:
        results_per_vocab = results[vocab_size]
        for tokenizer_name in results_per_vocab:
            names.append(tokenizer_name)
            values.append(list(results_per_vocab[tokenizer_name][i].values())[0])
            vocabs.append(vocab_size)
        
    data = pd.DataFrame({'tokenizer':names, 'values':values, 'vocabs':vocabs})
    if i < 5 :
        sns.factorplot(x='vocabs', y='values', hue='tokenizer', data=data, kind='bar')
        plt.title(list(results[500][tokenizer_name][i])[0])
        plt.show()
    else:
        for index, row in data.iterrows():
            name = row["tokenizer"]
            vocab_size = row["vocabs"]
            sns.countplot(row["values"]).set_title(f'Token length frequency for {name} with {vocab_size} vocab')
            plt.show()
