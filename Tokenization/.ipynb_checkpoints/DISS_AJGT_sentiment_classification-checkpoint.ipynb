# %%
# !wget https://raw.githubusercontent.com/komari6/Arabic-twitter-corpus-AJGT/master/AJGT.xlsx dataset/ajgt
# Out:
# Will not apply HSTS. The HSTS database must be a regular and non-world-writable file.
# ERROR: could not open HSTS store at '/home/zaid/.wget-hsts'. HSTS will be disabled.
# --2022-08-11 08:36:00--  https://raw.githubusercontent.com/komari6/Arabic-twitter-corpus-AJGT/master/AJGT.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107395 (105K) [application/octet-stream]
# Saving to: ‘AJGT.xlsx’
#
# AJGT.xlsx           100%[===================>] 104.88K  57.8KB/s    in 1.8s
#
# 2022-08-11 08:36:04 (57.8 KB/s) - ‘AJGT.xlsx’ saved [107395/107395]
#
# --2022-08-11 08:36:04--  http://dataset/ajgt
# Resolving dataset (dataset)... failed: Name or service not known.
# wget: unable to resolve host address ‘dataset’
# FINISHED --2022-08-11 08:36:06--
# ...

# %%
# !pip install git+https://github.com/ARBML/tkseem
# !pip install git+https://github.com/ARBML/tnkeeh
# !pip install git+https://github.com/ARBML/bayanat
# Out:
# ...
#   Cloning https://github.com/ARBML/tkseem to /tmp/pip-req-build-5_6sm93l
#   Running command git clone --filter=blob:none -q https://github.com/ARBML/tkseem /tmp/pip-req-build-5_6sm93l

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('AJGT.xlsx')

train_df_init = df.sample(frac=0.9,random_state=200)
test_df = df.drop(train_df_init.index) 

train_df = train_df_init.sample(frac=0.9,random_state=200)
valid_df  = train_df_init.drop(train_df.index)

# %%
len(train_df), len(valid_df) ,len(test_df)
# Out:
# (1458, 162, 180)

# %%
def map_to_label(sentiment):
  if sentiment == 'Negative':
    return '0'
  else:
    return '1'

def write_dataset(df, mode='train'):
  tweets = []
  labels = []

  for id_, record in df.iterrows():
      tweet, sentiment = record["Feed"], record["Sentiment"]
      tweets.append(tweet)
      labels.append(map_to_label(sentiment))
      
  open(f'{mode}_data.txt', 'w').write(('\n').join(tweets))
  open(f'{mode}_labels.txt', 'w').write(('\n').join(labels))

# %%
write_dataset(train_df, 'train')
write_dataset(valid_df, 'valid')
write_dataset(test_df,'test')

# %%
from bayanat import Bayanat
data = Bayanat('train_data.txt')
print(data.get_size_vocab())
print(data.get_number_of_words())
# Out:
# 6453
# 11689

# %%
import numpy as np
max_word_tokens = int(np.mean([len(stmt.split(' ')) for stmt in data.data.split('\n')]))
max_char_tokens = int(np.mean([len(stmt) for stmt in data.data.split('\n')]))

print(max_word_tokens)
print(max_char_tokens)
# Out:
# 9
# 46

# %%
from bayanat import Bayanat
data = Bayanat('test_data.txt')
print(data.get_size_vocab())
print(data.get_number_of_words())
# Out:
# 1101
# 1486

# %%
# %cd /content/
# !rm -r bpe-surgery
# !git clone https://zaidalyafeai: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@github.com/zaidalyafeai/bpe-surgery.git
# %cd bpe-surgery
# Out:
# /content
# Cloning into 'bpe-surgery'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 62 (delta 35), reused 25 (delta 11), pack-reused 0
# Unpacking objects: 100% (62/62), done.
# /content/bpe-surgery

# %%
# !cp ../drive/MyDrive/DISS/morfessor.bin .

# %%
l = max_word_tokens
r = max_char_tokens
path = '/content/drive/MyDrive/DISS/Tokenization/AJGTv2'

for v in [100, 500, 1000, 1500, 2000, 3000, 4000, 5000]:
  for j in range(0, 2):
    for i in range(0, 30):
      # !python3 script.py --tok {j} --run {i} --vocab_size {v} --max_word_tokens {l} --max_char_tokens {r} --dir {path}
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 9 Valid Loss 1.9813 Accuracy 0.7593
# Time taken for 1 epoch: 0.32683539390563965 secs
#
# Epoch 10 Train Loss 0.0000 Accuracy 1.0000
# Epoch 10 Valid Loss 2.2000 Accuracy 0.7593
# Time taken for 1 epoch: 0.36371588706970215 secs
#
# Epoch 11 Train Loss 0.0000 Accuracy 1.0000
# Epoch 11 Valid Loss 2.3343 Accuracy 0.7531
# Time taken for 1 epoch: 0.3316984176635742 secs
#
# Epoch 12 Train Loss 0.0000 Accuracy 1.0000
# Epoch 12 Valid Loss 2.4152 Accuracy 0.7531
# Time taken for 1 epoch: 0.32758593559265137 secs
#
# Epoch 13 Train Loss 0.0000 Accuracy 1.0000
# Epoch 13 Valid Loss 2.4639 Accuracy 0.7469
# Time taken for 1 epoch: 0.33098387718200684 secs
#
# Epoch 14 Train Loss 0.0000 Accuracy 1.0000
# Epoch 14 Valid Loss 2.4927 Accuracy 0.7469
# Time taken for 1 epoch: 0.3270728588104248 secs
#
# Epoch 15 Train Loss 0.0000 Accuracy 1.0000
# Epoch 15 Valid Loss 2.5100 Accuracy 0.7469
# ...

# %%
import glob
import json
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = []
path = '/content/drive/MyDrive/DISS/Tokenization/AJGTv2/ckpts/**/accuracies.json'

for path in glob.glob(path):
  start = path.find('vocab_size_')
  end = path.find('/accuracies.json')
  vocab_size = path[start+11:end]
  dd = json.load(open(path, mode='r'))
  for tokenizer in dd:
    results = dd[tokenizer]
    for val in results:
      data.append([vocab_size]+[tokenizer]+[float(val)])
df = pd.DataFrame(data, columns = ['vocab_size', 'tokenizer', 'accuracy'])
g = sns.boxplot(x="vocab_size", y="accuracy", hue="tokenizer",
                 data=df, palette="Set3")
# g.set(ylim=(0, 1))

# %%
# !cp script.py {path}'/script.py'
